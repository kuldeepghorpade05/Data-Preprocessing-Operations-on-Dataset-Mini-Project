# %%
#= miniproject by:-

NAME - KULDEEP GHORPADE

TOPIC -  data preprocessing operations on the dataset
Using Logistic regression, decision tree and Random Forest
algorithm and comparing the accuracy of the model

Dataset - lung cancer prediction =#

# %%
using Pkg
Pkg.add("CSV")
# Out:
#     Updating registry at `C:\Users\kulde\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`

# %%
using CSV

# %%
using DataFrames

# %%
iris=CSV.read("lungcancer.csv",DataFrame)
# Out:
# 1000×26 DataFrame
#   Row │ index  Patient Id  Age    Gender  Air Pollution  Alcohol use  Dust All ⋯
#       │ Int64  String7     Int64  Int64   Int64          Int64        Int64    ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     0  P1             33       1              2            4           ⋯
#     2 │     1  P10            17       1              3            1
#     3 │     2  P100           35       1              4            5
#     4 │     3  P1000          37       1              7            7
#     5 │     4  P101           46       1              6            8           ⋯
#     6 │     5  P102           35       1              4            5
#     7 │     6  P103           52       2              2            4
#     8 │     7  P104           28       2              3            1
#     9 │     8  P105           35       2              4            5           ⋯
# ...

# %%
lungcancer=CSV.read("lungcancer.csv",DataFrame,normalizenames=true)
# Out:
# 1000×26 DataFrame
#   Row │ index  Patient_Id  Age    Gender  Air_Pollution  Alcohol_use  Dust_All ⋯
#       │ Int64  String7     Int64  Int64   Int64          Int64        Int64    ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     0  P1             33       1              2            4           ⋯
#     2 │     1  P10            17       1              3            1
#     3 │     2  P100           35       1              4            5
#     4 │     3  P1000          37       1              7            7
#     5 │     4  P101           46       1              6            8           ⋯
#     6 │     5  P102           35       1              4            5
#     7 │     6  P103           52       2              2            4
#     8 │     7  P104           28       2              3            1
#     9 │     8  P105           35       2              4            5           ⋯
# ...

# %%
typeof(lungcancer)
# Out:
# DataFrame

# %%
names(lungcancer)
# Out:
# 26-element Vector{String}:
#  "index"
#  "Patient_Id"
#  "Age"
#  "Gender"
#  "Air_Pollution"
#  "Alcohol_use"
#  "Dust_Allergy"
#  "OccuPational_Hazards"
#  "Genetic_Risk"
#  "chronic_Lung_Disease"
#  "Balanced_Diet"
#  "Obesity"
#  "Smoking"
#  "Passive_Smoker"
#  "Chest_Pain"
#  "Coughing_of_Blood"
#  "Fatigue"
#  "Weight_Loss"
#  "Shortness_of_Breath"
#  "Wheezing"
#  "Swallowing_Difficulty"
#  "Clubbing_of_Finger_Nails"
#  "Frequent_Cold"
#  "Dry_Cough"
#  "Snoring"
#  "Level"

# %%
size(lungcancer)
# Out:
# (1000, 26)

# %%
first(lungcancer,5)
# Out:
# 5×26 DataFrame
#  Row │ index  Patient_Id  Age    Gender  Air_Pollution  Alcohol_use  Dust_Alle ⋯
#      │ Int64  String7     Int64  Int64   Int64          Int64        Int64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     0  P1             33       1              2            4            ⋯
#    2 │     1  P10            17       1              3            1
#    3 │     2  P100           35       1              4            5
#    4 │     3  P1000          37       1              7            7
#    5 │     4  P101           46       1              6            8            ⋯
#                                                               20 columns omitted

# %%
last(lungcancer,5)
# Out:
# 5×26 DataFrame
#  Row │ index  Patient_Id  Age    Gender  Air_Pollution  Alcohol_use  Dust_Alle ⋯
#      │ Int64  String7     Int64  Int64   Int64          Int64        Int64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   995  P995           44       1              6            7            ⋯
#    2 │   996  P996           37       2              6            8
#    3 │   997  P997           25       2              4            5
#    4 │   998  P998           18       2              6            8
#    5 │   999  P999           47       1              6            5            ⋯
#                                                               20 columns omitted

# %%
describe(lungcancer)
# Out:
# 26×7 DataFrame
#  Row │ variable                  mean    min   median  max     nmissing  eltyp ⋯
#      │ Symbol                    Union…  Any   Union…  Any     Int64     DataT ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ index                     499.5   0     499.5   999            0  Int64 ⋯
#    2 │ Patient_Id                        P1            P999           0  Strin
#    3 │ Age                       37.174  14    36.0    73             0  Int64
#    4 │ Gender                    1.402   1     1.0     2              0  Int64
#    5 │ Air_Pollution             3.84    1     3.0     8              0  Int64 ⋯
#    6 │ Alcohol_use               4.563   1     5.0     8              0  Int64
#    7 │ Dust_Allergy              5.165   1     6.0     8              0  Int64
#    8 │ OccuPational_Hazards      4.84    1     5.0     8              0  Int64
# ...

# %%
lungcancer.Air_Pollution
# Out:
# 1000-element Vector{Int64}:
#  2
#  3
#  4
#  7
#  6
#  4
#  2
#  3
#  4
#  2
#  6
#  6
#  4
#  ⋮
#  6
#  7
#  6
#  8
#  7
#  7
#  6
#  6
#  6
#  4
#  6
#  6

# %%
lungcancer[:,3]
# Out:
# 1000-element Vector{Int64}:
#  33
#  17
#  35
#  37
#  46
#  35
#  52
#  28
#  35
#  46
#  44
#  64
#  39
#   ⋮
#  39
#  37
#  49
#  37
#  26
#  37
#  33
#  44
#  37
#  25
#  18
#  47

# %%
lungcancer[:,[1,2,3]]
# Out:
# 1000×3 DataFrame
#   Row │ index  Patient_Id  Age
#       │ Int64  String7     Int64
# ──────┼──────────────────────────
#     1 │     0  P1             33
#     2 │     1  P10            17
#     3 │     2  P100           35
#     4 │     3  P1000          37
#     5 │     4  P101           46
#     6 │     5  P102           35
#     7 │     6  P103           52
#     8 │     7  P104           28
#     9 │     8  P105           35
#    10 │     9  P106           46
#    11 │    10  P107           44
#   ⋮   │   ⋮        ⋮         ⋮
#   991 │   990  P990           49
#   992 │   991  P991           37
#   993 │   992  P992           26
#   994 │   993  P993           37
#   995 │   994  P994           33
#   996 │   995  P995           44
#   997 │   996  P996           37
#   998 │   997  P997           25
#   999 │   998  P998           18
#  1000 │   999  P999           47
#                  979 rows omitted

# %%
lungcancer[1:5,:]
# Out:
# 5×26 DataFrame
#  Row │ index  Patient_Id  Age    Gender  Air_Pollution  Alcohol_use  Dust_Alle ⋯
#      │ Int64  String7     Int64  Int64   Int64          Int64        Int64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     0  P1             33       1              2            4            ⋯
#    2 │     1  P10            17       1              3            1
#    3 │     2  P100           35       1              4            5
#    4 │     3  P1000          37       1              7            7
#    5 │     4  P101           46       1              6            8            ⋯
#                                                               20 columns omitted

# %%
lungcancer[1:5,1:2]
# Out:
# 5×2 DataFrame
#  Row │ index  Patient_Id
#      │ Int64  String7
# ─────┼───────────────────
#    1 │     0  P1
#    2 │     1  P10
#    3 │     2  P100
#    4 │     3  P1000
#    5 │     4  P101

# %%
# exp 10

# %%
using Pkg

# %%
Pkg.add("Pandas")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`

# %%
using Pandas
# Out:
# WARNING: using Pandas.DataFrame in module Main conflicts with an existing identifier.
# WARNING: using Pandas.describe in module Main conflicts with an existing identifier.

# %%
using Pandas

# %%
df_train=read_csv("lungcancer.csv")
# Out:
#      index Patient Id  Age  Gender  ...  Frequent Cold  Dry Cough  Snoring   Level
# 0        0         P1   33       1  ...              2          3        4     Low
# 1        1        P10   17       1  ...              1          7        2  Medium
# 2        2       P100   35       1  ...              6          7        2    High
# 3        3      P1000   37       1  ...              6          7        5    High
# 4        4       P101   46       1  ...              4          2        3    High
# ..     ...        ...  ...     ...  ...            ...        ...      ...     ...
# 995    995       P995   44       1  ...              4          5        3    High
# 996    996       P996   37       2  ...              3          1        4    High
# 997    997       P997   25       2  ...              6          7        2    High
# 998    998       P998   18       2  ...              4          2        3    High
# ...

# %%
x=df_train[["Air Pollution","Alcohol use","Dust Allergy","Genetic Risk"]]
y = df_train["Level"]
# Out:
# 0         Low
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 995      High
# 996      High
# 997      High
# 998      High
# 999      High
# Name: Level, Length: 1000, dtype: object

# %%
Pkg.add("ScikitLearn")
Pkg.update()
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`
#     Updating registry at `C:\Users\kulde\.julia\registries\General.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`

# %%
using Pkg
Pkg.add("sklearn")
# Out:
# The following package names could not be resolved:
#  * sklearn (not found in project, manifest or registry)
#    Suggestions: ScikitLearn ScikitLearnBase MLJScikitLearn
#
# Stacktrace:
#   [1] pkgerror(msg::String)
#     @ Pkg.Types C:\Users\kulde\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\Types.jl:67
#   [2] ensure_resolved(ctx::Pkg.Types.Context, manifest::Pkg.Types.Manifest, pkgs::Vector{Pkg.Types.PackageSpec}; registry::Bool)
#     @ Pkg.Types C:\Users\kulde\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\Types.jl:952
#   [3] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, kwargs::Base.Pairs{Symbol, IJulia.IJuliaStdio{Base.PipeEndpoint}, Tuple{Symbol}, NamedTuple{(:io,), Tuple{IJulia.IJuliaStdio{Base.PipeEndpoint}}}})
#     @ Pkg.API C:\Users\kulde\AppData\Local\Programs\Julia-1.8.3\share\julia\stdlib\v1.8\Pkg\src\API.jl:264
# ...

# %%
using ScikitLearn: fit!, predict, @sk_import, fit_transform!

# %%
@sk_import model_selection: train_test_split
# Out:
# ┌ Warning: Module model_selection has been ported to Julia - try `import ScikitLearn: CrossValidation` instead
# └ @ ScikitLearn.Skcore C:\Users\kulde\.julia\packages\ScikitLearn\7Csem\src\Skcore.jl:193
# PyObject <function train_test_split at 0x000002398CEE6B90>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# Out:
# 4-element Vector{PyCall.PyObject}:
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 541              6            7             7             7
# 440              6            7             7             7
# 482              2            3             6             7
# 422              6            7             7             7
# 778              3            1             4             3
# ..             ...          ...           ...           ...
# 106              6            7             7             7
# 270              1            2             2             2
# 860              2            1             5             2
# 435              6            5             6             5
# 102              6            5             6             5
#
# [700 rows x 4 columns]
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 521              1            6             7             7
# ...

# %%
@sk_import linear_model: LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# PyObject LogisticRegression()

# %%
println("Predicted Accuracy of the Model : ",model.score(x_test,y_test))
println("Actual Accuracy of the Model : ",model.score(x_train,y_train))
# Out:
# Predicted Accuracy of the Model : 0.7
# Actual Accuracy of the Model : 0.6957142857142857

# %%
@sk_import model_selection: cross_val_score
# Out:
# ┌ Warning: Module model_selection has been ported to Julia - try `import ScikitLearn: CrossValidation` instead
# └ @ ScikitLearn.Skcore C:\Users\kulde\.julia\packages\ScikitLearn\7Csem\src\Skcore.jl:193
# PyObject <function cross_val_score at 0x000002398CFC6EF0>

# %%
#5 fold cross validation
 cross_score = cross_val_score(model, x, y, cv=5)
 #print cross_val_score
 println("cross_validation_score: ", mean(cross_score))
# Out:
# cross_validation_score: 0.69

# %%
# exp 11

# %%
using Pandas

# %%
df_train=read_csv("lungcancer.csv")
# Out:
#      index Patient Id  Age  Gender  ...  Frequent Cold  Dry Cough  Snoring   Level
# 0        0         P1   33       1  ...              2          3        4     Low
# 1        1        P10   17       1  ...              1          7        2  Medium
# 2        2       P100   35       1  ...              6          7        2    High
# 3        3      P1000   37       1  ...              6          7        5    High
# 4        4       P101   46       1  ...              4          2        3    High
# ..     ...        ...  ...     ...  ...            ...        ...      ...     ...
# 995    995       P995   44       1  ...              4          5        3    High
# 996    996       P996   37       2  ...              3          1        4    High
# 997    997       P997   25       2  ...              6          7        2    High
# 998    998       P998   18       2  ...              4          2        3    High
# ...

# %%
x=df_train[["Air Pollution","Alcohol use","Dust Allergy","Genetic Risk"]]
y = df_train["Level"]
# Out:
# 0         Low
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 995      High
# 996      High
# 997      High
# 998      High
# 999      High
# Name: Level, Length: 1000, dtype: object

# %%
using ScikitLearn: fit!, predict, @sk_import, fit_transform!

# %%
@sk_import model_selection: train_test_split
# Out:
# ┌ Warning: Module model_selection has been ported to Julia - try `import ScikitLearn: CrossValidation` instead
# └ @ ScikitLearn.Skcore C:\Users\kulde\.julia\packages\ScikitLearn\7Csem\src\Skcore.jl:193
# WARNING: redefinition of constant train_test_split. This may fail, cause incorrect answers, or produce other errors.
# PyObject <function train_test_split at 0x000002398CEE6B90>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# Out:
# 4-element Vector{PyCall.PyObject}:
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 541              6            7             7             7
# 440              6            7             7             7
# 482              2            3             6             7
# 422              6            7             7             7
# 778              3            1             4             3
# ..             ...          ...           ...           ...
# 106              6            7             7             7
# 270              1            2             2             2
# 860              2            1             5             2
# 435              6            5             6             5
# 102              6            5             6             5
#
# [700 rows x 4 columns]
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 521              1            6             7             7
# ...

# %%
@sk_import tree: DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
println("Predicted Accuracy of the Model : ",model.score(x_test,y_test))
println("Actual Accuracy of the Model : ",model.score(x_train,y_train))
# Out:
# Predicted Accuracy of the Model : 0.9066666666666666
# Actual Accuracy of the Model : 0.9114285714285715

# %%
@sk_import model_selection: cross_val_score
# Out:
# ┌ Warning: Module model_selection has been ported to Julia - try `import ScikitLearn: CrossValidation` instead
# └ @ ScikitLearn.Skcore C:\Users\kulde\.julia\packages\ScikitLearn\7Csem\src\Skcore.jl:193
# WARNING: redefinition of constant cross_val_score. This may fail, cause incorrect answers, or produce other errors.
# PyObject <function cross_val_score at 0x000002398CFC6EF0>

# %%
#5 fold cross validation
 cross_score = cross_val_score(model, x, y, cv=5)
 #print cross_val_score
 println("cross_validation_score: ", mean(cross_score))
# Out:
# cross_validation_score: 0.9100000000000001

# %%
# exp 12

# %%
using Pandas

# %%
df_train=read_csv("lungcancer.csv")
# Out:
#      index Patient Id  Age  Gender  ...  Frequent Cold  Dry Cough  Snoring   Level
# 0        0         P1   33       1  ...              2          3        4     Low
# 1        1        P10   17       1  ...              1          7        2  Medium
# 2        2       P100   35       1  ...              6          7        2    High
# 3        3      P1000   37       1  ...              6          7        5    High
# 4        4       P101   46       1  ...              4          2        3    High
# ..     ...        ...  ...     ...  ...            ...        ...      ...     ...
# 995    995       P995   44       1  ...              4          5        3    High
# 996    996       P996   37       2  ...              3          1        4    High
# 997    997       P997   25       2  ...              6          7        2    High
# 998    998       P998   18       2  ...              4          2        3    High
# ...

# %%
x=df_train[["Air Pollution","Alcohol use","Dust Allergy","Genetic Risk"]]
y = df_train["Level"]
# Out:
# 0         Low
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 995      High
# 996      High
# 997      High
# 998      High
# 999      High
# Name: Level, Length: 1000, dtype: object

# %%
using ScikitLearn: fit!, predict, @sk_import, fit_transform!

# %%
@sk_import model_selection: train_test_split
# Out:
# ┌ Warning: Module model_selection has been ported to Julia - try `import ScikitLearn: CrossValidation` instead
# └ @ ScikitLearn.Skcore C:\Users\kulde\.julia\packages\ScikitLearn\7Csem\src\Skcore.jl:193
# WARNING: redefinition of constant train_test_split. This may fail, cause incorrect answers, or produce other errors.
# PyObject <function train_test_split at 0x000002398CEE6B90>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# Out:
# 4-element Vector{PyCall.PyObject}:
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 541              6            7             7             7
# 440              6            7             7             7
# 482              2            3             6             7
# 422              6            7             7             7
# 778              3            1             4             3
# ..             ...          ...           ...           ...
# 106              6            7             7             7
# 270              1            2             2             2
# 860              2            1             5             2
# 435              6            5             6             5
# 102              6            5             6             5
#
# [700 rows x 4 columns]
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 521              1            6             7             7
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# Out:
# 4-element Vector{PyCall.PyObject}:
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 541              6            7             7             7
# 440              6            7             7             7
# 482              2            3             6             7
# 422              6            7             7             7
# 778              3            1             4             3
# ..             ...          ...           ...           ...
# 106              6            7             7             7
# 270              1            2             2             2
# 860              2            1             5             2
# 435              6            5             6             5
# 102              6            5             6             5
#
# [700 rows x 4 columns]
#  PyObject      Air Pollution  Alcohol use  Dust Allergy  Genetic Risk
# 521              1            6             7             7
# ...

# %%
@sk_import model_selection: cross_val_score
# Out:
# ┌ Warning: Module model_selection has been ported to Julia - try `import ScikitLearn: CrossValidation` instead
# └ @ ScikitLearn.Skcore C:\Users\kulde\.julia\packages\ScikitLearn\7Csem\src\Skcore.jl:193
# WARNING: redefinition of constant cross_val_score. This may fail, cause incorrect answers, or produce other errors.
# PyObject <function cross_val_score at 0x000002398CFC6EF0>

# %%
#5 fold cross validation
 cross_score = cross_val_score(model, x, y, cv=5)
 #print cross_val_score
 println("cross_validation_score: ", mean(cross_score))
# Out:
# cross_validation_score: 0.9100000000000001
